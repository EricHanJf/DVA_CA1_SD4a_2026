# %% [markdown]
# ## Normalisation

# %% [markdown]
# ## 1. loading the cleaned dataset

# %%
import pandas as pd
import numpy as np

slqi_dataset = pd.read_csv("../Dataset/final_SLQI_dataset.csv")
slqi_dataset.head()
# Out:
#           Country Country Code  gdp_per_capita  inflation  unemployment_rate  \
# 0     Afghanistan          AFG      413.757895  -6.601186            13.6870
# 1         Albania          ALB    11377.775743   2.215874            10.6890
# 2         Algeria          DZA     5752.990767   4.046115            11.6550
# 3  American Samoa          ASM    18017.458938   3.117464             5.1895
# 4         Andorra          AND    49303.649167   3.117464             5.1895
#
#    life_expectancy  secondary_enrollment  electricity_access  \
# 0           66.289             59.613602                85.3
# 1           79.776            108.355392               100.0
# 2           76.475            105.164132               100.0
# 3           72.992             92.659564               100.0
# 4           84.188            101.923820               100.0
#
#    drinking_water_access  sanitation_access  government_effectiveness  \
# 0              80.832437          54.495799                 -1.933997
# 1              95.119427          99.299715                  0.312344
# 2              92.420029          85.906486                 -0.251191
# 3             100.000000          62.119698                  0.767382
# 4             100.000000         100.000000                  1.159037
#
#    political_stability  rule_of_law  forest_area  pm25_exposure  \
# 0            -2.205211    -1.935489     1.852782      46.087094
# 1             0.020467    -0.118502    28.791971      15.707004
# 2            -0.693588    -0.696777     0.830314      25.552656
# 3             1.253029     1.086581    85.200000       6.715147
# 4             1.543796     1.409905    34.042553       9.080281
#
#    renewable_energy
# 0              20.0
# 1              41.9
# 2               0.1
# 3               0.4
# 4              18.7

# %% [markdown]
# ## 2. Select indicators

# %%
indicator_cols = [
    "gdp_per_capita",
    "inflation",
    "unemployment_rate",
    "life_expectancy",
    "secondary_enrollment",
    "electricity_access",
    "drinking_water_access",
    "sanitation_access",
    "government_effectiveness",
    "political_stability",
    "rule_of_law",
    "forest_area",
    "pm25_exposure",
    "renewable_energy"
]
