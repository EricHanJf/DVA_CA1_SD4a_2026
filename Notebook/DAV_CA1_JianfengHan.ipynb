# %% [markdown]
# # International Education Cost Index by Country

# %% [markdown]
# ## 1. Introduction
#
# For students seeking academic, professional, and personal development opportunities abroad, international education has become a popular and important choice. However, studying in another country involves many financial costs, including tuition fees, living expenses, accommodation, visa charges, and insurance costs. These costs vary significantly across countries, making direct comparison difficult when only a single variable is considered.
#
# As an international student myself, I understand that the decision to study abroad is not based only on academic interest or university reputation. Financial pressure is also a very important part of the decision-making process. In reality, students often need to think not only about tuition fees, but also about rent, daily living costs, visa-related expenses, and other necessary payments. Sometimes a country may seem affordable at first because of lower tuition fees, but the actual cost of living can still make it expensive overall. From my perspective, this makes cross-country comparison more complex and more meaningful than simply comparing one cost variable.
#
# For this reason, this project uses the *Cost of International Education* dataset to develop an **International Education Cost Index by Country**. The purpose of this index is to provide a clearer and more structured comparison of the financial burden faced by international students across different countries.
#
# Rather than focusing on only one cost indicator, this project combines multiple cost-related variables into a composite index. This makes it possible to capture the multidimensional nature of international education costs and to identify countries with relatively higher or lower overall costs.
#
# The analysis in this project focuses on country-level comparison. The selected indicators will be aggregated, normalised, and combined into sub-indices and a final composite index. The results will then be analysed and visualised to highlight patterns and differences in international education costs across countries.

# %% [markdown]
# ## 2. Theoretical Framework
#
# A composite index is used to measure a multidimensional concept by combining several related indicators into a single overall score. In this project, the concept being measured is the **cost of international education** at country level.
#
# The cost of studying abroad cannot be represented accurately by a single variable. Although tuition fees are often one of the main expenses for international students, they are not the only cost involved. Students also need to consider accommodation, day-to-day living expenses, visa costs, and insurance charges. As a result, two countries may appear similar in terms of tuition fees but differ significantly in their overall cost once other expenses are taken into account. For this reason, a composite index is a more appropriate tool for comparing the financial burden of international education across countries.
#
# In this project, the index is structured around three main dimensions.
# ### 2.1 Tuition Cost
# This dimension represents the direct academic cost of studying in a country. Tuition fees usually make up the largest single cost for international students and therefore form an essential part of the index.
# - **Tuition_USD**
#
# ### 2.2 Living Cost
# This dimension represents the general cost of living associated with studying in a country. It includes both overall living expenses and accommodation-related cost.
# - **Living_Cost_Index**
# - **Rent_USD**
#
# These variables are important because even when tuition fees are relatively affordable, high living or housing costs can still make a country expensive overall.
#
# ### 2.3 Additional Mandatory Costs
# This dimension captures extra costs that international students are often required to pay in addition to tuition and living expenses.
# - **Visa_Fee**
# - **Insurance_USD**
#
# Although these costs may be smaller than tuition or rent, they still contribute to the total financial burden and should be included in the index.
#
# ### 2.4 Variables not included in the final index
# Some variables in the dataset are useful for context, description, or grouping, but are not included directly in the final composite index.
# - **Country** is used as the main unit of comparison rather than as an indicator.
# - **City**, **University**, **Program**, and **Level** are descriptive variables and do not directly measure cost at country level.
# - **Duration** may be relevant when estimating total full-programme cost, but this project focuses on comparing cost indicators directly rather than calculating the full cost of an entire degree.
# - **Exchange_Rate** is not included in the final index because the main monetary variables are already expressed in USD, which makes direct comparison possible without using exchange rate as a separate indicator.
#
# Overall, this framework treats international education cost as a multidimensional concept made up of tuition cost, living cost, and additional mandatory expenses. This structure provides the basis for selecting indicators, aggregating the data at country level, and constructing the final composite index.

# %% [markdown]
# ## 3. Data Selection

# %% [markdown]
# ## 4. Data Cleaning and Missing Data

# %% [markdown]
# ## 5. Multivariate Analysis

# %% [markdown]
# ## 6. Normalisation

# %% [markdown]
# ## 7. Weighting and Aggregation

# %% [markdown]
# ## 8. Link to Other Indices

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# Load dataset
df = pd.read_csv("International_Education_Costs.csv")

# Preview dataset
df.head()
# Out:
#      Country       City                      University  \
# 0        USA  Cambridge              Harvard University
# 1         UK     London         Imperial College London
# 2     Canada    Toronto           University of Toronto
# 3  Australia  Melbourne         University of Melbourne
# 4    Germany     Munich  Technical University of Munich
#
#                   Program   Level  Duration_Years  Tuition_USD  \
# 0        Computer Science  Master             2.0        55400
# 1            Data Science  Master             1.0        41200
# 2      Business Analytics  Master             2.0        38500
# 3             Engineering  Master             2.0        42000
# 4  Mechanical Engineering  Master             2.0          500
#
#    Living_Cost_Index  Rent_USD  Visa_Fee_USD  Insurance_USD  Exchange_Rate
# 0               83.5      2200           160           1500           1.00
# 1               75.8      1800           485            800           0.79
# ...
